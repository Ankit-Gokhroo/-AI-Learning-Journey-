# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-Gokhroo/-AI-Learning-Journey-/blob/main/4_stopWords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
stemmer = PorterStemmer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
corpus = """My dear young friends, I stand before you today, not just as a former President, but as a fellow dreamer—someone who believes that each one of you has the power to transform India. Dreams, you know, are not those which come while you are sleeping; rather, dreams are those that do not let you sleep! When I was a small boy in Rameswaram, I often wondered, ‘Can I really make a difference?’ The answer, I discovered, lies within ourselves. You must ask: what will I give to the nation? Not ‘what will the nation give me?’ because true success doesn’t come from taking—it comes from giving, striving, and persisting.

Education, dedication, and hard work—these are the keys; however, one must also have courage, curiosity, and compassion. Sometimes, you may fail (and that’s okay!), but remember: failure is not the opposite of success; it’s a part of success. If you learn from it, you grow. So, don’t fear failure—embrace it, analyze it, and move forward.

Let your vision be big, your actions be consistent, and your intentions be pure. Together, we can build a developed India—an India that is strong, self-reliant, and full of innovation. The journey may be long, the road may be tough, but with determination, discipline, and dreams, nothing is impossible.
"""

# %%
sentences = nltk.sent_tokenize(corpus)
sentences
# Out:
# ['My dear young friends, I stand before you today, not just as a former President, but as a fellow dreamer—someone who believes that each one of you has the power to transform India.',
#  'Dreams, you know, are not those which come while you are sleeping; rather, dreams are those that do not let you sleep!',
#  'When I was a small boy in Rameswaram, I often wondered, ‘Can I really make a difference?’ The answer, I discovered, lies within ourselves.',
#  'You must ask: what will I give to the nation?',
#  'Not ‘what will the nation give me?’ because true success doesn’t come from taking—it comes from giving, striving, and persisting.',
#  'Education, dedication, and hard work—these are the keys; however, one must also have courage, curiosity, and compassion.',
#  'Sometimes, you may fail (and that’s okay!',
#  '), but remember: failure is not the opposite of success; it’s a part of success.',
#  'If you learn from it, you grow.',
# ...

# %%
#1 PorterStemmer
#apply stopwords and filter and then apply stemming
for i in range(len(sentences)):
  words = nltk.word_tokenize(sentences[i])
  words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
  sentences[i] = ' '.join(words) #converting all the list words into sentences

# %%
sentences
# Out:
# ['my dear young friend , i stand today , former presid , fellow dreamer—someon believ one power transform india .',
#  'dream , know , come sleep ; rather , dream let sleep !',
#  'when i small boy rameswaram , i often wonder , ‘ can i realli make differ ? ’ the answer , i discov , lie within .',
#  'you must ask : i give nation ?',
#  'not ‘ nation give ? ’ true success ’ come taking—it come give , strive , persist .',
#  'educ , dedic , hard work—thes key ; howev , one must also courag , curios , compass .',
#  'sometim , may fail ( ’ okay !',
#  ') , rememb : failur opposit success ; ’ part success .',
#  'if learn , grow .',
#  'so , ’ fear failure—embrac , analyz , move forward .',
#  'let vision big , action consist , intent pure .',
#  'togeth , build develop india—an india strong , self-reli , full innov .',
#  'the journey may long , road may tough , determin , disciplin , dream , noth imposs .']

# %%
from nltk.stem import SnowballStemmer
snowBallStem = SnowballStemmer('english')

# %%
#2 SnowballStemmer
#apply stopwords and filter and then apply stemming
for i in range(len(sentences)):
  words = nltk.word_tokenize(sentences[i])
  words = [snowBallStem.stem(word) for word in words if word not in set(stopwords.words('english'))]
  sentences[i] = ' '.join(words) #converting all the list words into sentences

# %%
sentences
# Out:
# ['my dear young friend , i stand today , former presid , fellow dreamer—someon believ one power transform india .',
#  'dream , know , come sleep ; rather , dream let sleep !',
#  'when i small boy rameswaram , i often wonder , ‘ can i realli make differ ? ’ the answer , i discov , lie within .',
#  'you must ask : i give nation ?',
#  'not ‘ nation give ? ’ true success ’ come taking—it come give , strive , persist .',
#  'educ , dedic , hard work—thes key ; howev , one must also courag , curios , compass .',
#  'sometim , may fail ( ’ okay !',
#  ') , rememb : failur opposit success ; ’ part success .',
#  'if learn , grow .',
#  'so , ’ fear failure—embrac , analyz , move forward .',
#  'let vision big , action consist , intent pure .',
#  'togeth , build develop india—an india strong , self-reli , full innov .',
#  'the journey may long , road may tough , determin , disciplin , dream , noth imposs .']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
#3 lemmatize
#apply stopwords and filter and then apply stemming
for i in range(len(sentences)):
  words = nltk.word_tokenize(sentences[i])
  words = [lemmatizer.lemmatize(word.lower(), pos = 'v') for word in words if word not in set(stopwords.words('english'))]
  sentences[i] = ' '.join(words) #converting all the list words into sentences

# %%
sentences
# Out:
# ['dear young friends , stand today , former president , fellow dreamer—someone believe one power transform india .',
#  'dream , know , come sleep ; rather , dream let sleep !',
#  'small boy rameswaram , often wonder , ‘ really make difference ? ’ answer , discover , lie within .',
#  'must ask : give nation ?',
#  '‘ nation give ? ’ true success ’ come taking—it come give , strive , persist .',
#  'education , dedication , hard work—these key ; however , one must also courage , curiosity , compassion .',
#  'sometimes , may fail ( ’ okay !',
#  ') , remember : failure opposite success ; ’ part success .',
#  'learn , grow .',
#  ', ’ fear failure—embrace , analyze , move forward .',
#  'let vision big , action consistent , intentions pure .',
#  'together , build develop india—an india strong , self-reliant , full innovation .',
#  'journey may long , road may tough , determination , discipline , dream , nothing impossible .']
